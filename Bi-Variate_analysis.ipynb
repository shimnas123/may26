# %% [markdown]
# (ii.)Bi-variate analysis

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df=pd.read_csv("House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
#Corelation 
df.corr()
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
# Scatter plot for the Condition of house and  the price
x=df['condition of the house']
y=df['Price']
plt.scatter(x,y)
plt.xlabel('Condition of the house')
plt.ylabel('Price ')
plt.title('Scatter plot of Condition of th house and Price')
plt.show()

# %%
# Scatter plot for the Condition of house and  the price
x=df['number of bedrooms']
y=df['number of bathrooms']
plt.scatter(x,y)
plt.xlabel('Number of bedrooms')
plt.ylabel('Number of bathrooms ')
plt.title('Scatter plot of Number of bedrooms and number of bathrooms')
plt.show()

# %%
# Scatter plot for LLiving area and lot area
x=df['living area']
y=df['lot area']
plt.scatter(x,y)
plt.xlabel('Living area')
plt.ylabel('lot area')
plt.title('Scatter plot for Living area and lot area')
plt.show()

# %%
 #Bar plot for LLiving area and lot area
x=df['living area']
y=df['lot area']
plt.bar(x,y)
plt.xlabel('Living area')
plt.ylabel('lot area')
plt.title('bar for Living area and lot area')
plt.show()

# %%
# Bar for the Condition of house and  the price
x=df['number of bedrooms']
y=df['number of bathrooms']
plt.bar(x,y)
plt.xlabel('Number of bedrooms')
plt.ylabel('Number of bathrooms ')
plt.title('Bar of Number of bedrooms and number of bathrooms')
plt.show()
